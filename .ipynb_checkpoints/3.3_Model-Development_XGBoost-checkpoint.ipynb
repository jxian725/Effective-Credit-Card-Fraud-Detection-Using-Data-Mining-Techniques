# %%
import pandas as pd
import pickle

# Load train_dataset 
train_data = pd.read_csv('datasets/train_dataset.csv')

# Separate features and target
X = train_data.drop(['isFraud'], axis=1)
y = train_data['isFraud']

# Load the 10-fold indices
with open("10_fold_indices.pkl", "rb") as f:
    splits = pickle.load(f)

print(f"Loaded {len(splits)} folds.")
# Out:
# Loaded 10 folds.

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import (
    roc_auc_score, accuracy_score, precision_score, recall_score, f1_score
)
import os
import pickle

# -------------------- XGBoost Parameters --------------------
params = {
    "objective": "binary:logistic",
    "eval_metric": "auc",
    "learning_rate": 0.05,
    "max_depth": 6,
    "subsample": 0.8,
    "colsample_bytree": 0.8,
    "random_state": 42,
    "n_jobs": -1,
    "tree_method": "hist",
    "device": "cuda"
}

# -------------------- Setup --------------------
os.makedirs("models/xgboost", exist_ok=True)

auc_scores = []
accuracy_scores = []
precision_0, precision_1 = [], []
recall_0, recall_1 = [], []
f1_0, f1_1 = [], []

categorical_cols = X.select_dtypes(include="object").columns.tolist()

# -------------------- Cross-Validation --------------------
for fold, (train_idx, val_idx) in enumerate(splits, 1):
    print(f"\n Fold {fold}")

    X_train, X_val = X.iloc[train_idx].copy(), X.iloc[val_idx].copy()
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

    # Label Encoding
    for col in categorical_cols:
        le = LabelEncoder()
        combined = pd.concat([X_train[col], X_val[col]], axis=0)
        le.fit(combined)
        X_train[col] = le.transform(X_train[col])
        X_val[col] = le.transform(X_val[col])

    # Scale numeric features
    numeric_cols = X_train.select_dtypes(include=["int64", "float64"]).columns.tolist()
    scaler = StandardScaler()
    X_train[numeric_cols] = scaler.fit_transform(X_train[numeric_cols])
    X_val[numeric_cols] = scaler.transform(X_val[numeric_cols])

    # Train XGBoost
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dval = xgb.DMatrix(X_val, label=y_val)

    model = xgb.train(
        params=params,
        dtrain=dtrain,
        num_boost_round=5000,
        evals=[(dval, "validation")],
        early_stopping_rounds=50,
        verbose_eval=50
    )

    # Predict and Evaluate
    y_val_prob = model.predict(dval, iteration_range=(0, model.best_iteration))
    y_val_pred = (y_val_prob > 0.5).astype(int)

    auc = roc_auc_score(y_val, y_val_prob)
    acc = accuracy_score(y_val, y_val_pred)
    prec = precision_score(y_val, y_val_pred, average=None, zero_division=0)
    rec = recall_score(y_val, y_val_pred, average=None)
    f1 = f1_score(y_val, y_val_pred, average=None)

    # Track metrics
    auc_scores.append(auc)
    accuracy_scores.append(acc)
    precision_0.append(prec[0])
    precision_1.append(prec[1])
    recall_0.append(rec[0])
    recall_1.append(rec[1])
    f1_0.append(f1[0])
    f1_1.append(f1[1])

    print(f" Fold {fold} AUC-ROC : {auc:.4f} | Best Iteration: {model.best_iteration}")
    print(f"   Accuracy     : {acc:.4f}")
    print(f"   Precision_0  : {prec[0]:.4f} | Precision_1 : {prec[1]:.4f}")
    print(f"   Recall_0     : {rec[0]:.4f} | Recall_1    : {rec[1]:.4f}")
    print(f"   F1 Score_0   : {f1[0]:.4f} | F1 Score_1  : {f1[1]:.4f}")

    # Save model
    model.save_model(f"models/xgboost/fold_{fold}.json")

# -------------------- Summary --------------------
print("\n Cross-Validation Summary (XGBoost + Label Encoding + Scaling)")
for i in range(len(auc_scores)):
    print(
        f"Fold {i+1}: AUC={auc_scores[i]:.4f} | Acc={accuracy_scores[i]:.4f} | "
        f"Prec_0={precision_0[i]:.4f} | Prec_1={precision_1[i]:.4f} | "
        f"Recall_0={recall_0[i]:.4f} | Recall_1={recall_1[i]:.4f} | "
        f"F1_0={f1_0[i]:.4f} | F1_1={f1_1[i]:.4f}"
    )

print("\n Final Averages:")
print(f"AUC-ROC     : {np.mean(auc_scores):.4f} ± {np.std(auc_scores):.4f}")
print(f"Accuracy    : {np.mean(accuracy_scores):.4f}")
print(f"Precision_0 : {np.mean(precision_0):.4f}")
print(f"Precision_1 : {np.mean(precision_1):.4f}")
print(f"Recall_0    : {np.mean(recall_0):.4f}")
print(f"Recall_1    : {np.mean(recall_1):.4f}")
print(f"F1 Score_0  : {np.mean(f1_0):.4f}")
print(f"F1 Score_1  : {np.mean(f1_1):.4f}")
# Out:
#  Fold 1
# [0]	validation-auc:0.78784
# [50]	validation-auc:0.88911
# [100]	validation-auc:0.90702
# [150]	validation-auc:0.91665
# [200]	validation-auc:0.92321
# [250]	validation-auc:0.92737
# [300]	validation-auc:0.93189
# [350]	validation-auc:0.93496
# [400]	validation-auc:0.93755
# [450]	validation-auc:0.93945
# [500]	validation-auc:0.94145
# [550]	validation-auc:0.94323
# [600]	validation-auc:0.94505
# [650]	validation-auc:0.94654
# [700]	validation-auc:0.94805
# [750]	validation-auc:0.94881
# [800]	validation-auc:0.95016
# [850]	validation-auc:0.95150
# [900]	validation-auc:0.95256
# [950]	validation-auc:0.95345
# [1000]	validation-auc:0.95431
# [1050]	validation-auc:0.95546
# [1100]	validation-auc:0.95609
# [1150]	validation-auc:0.95682
# [1200]	validation-auc:0.95767
# [1250]	validation-auc:0.95848
# [1300]	validation-auc:0.95947
# [1350]	validation-auc:0.96012
# [1400]	validation-auc:0.96073
# [1450]	validation-auc:0.96125
# [1500]	validation-auc:0.96193
# [1550]	validation-auc:0.96246
# [1600]	validation-auc:0.96281
# [1650]	validation-auc:0.96324
# [1700]	validation-auc:0.96383
# [1750]	validation-auc:0.96425
# [1800]	validation-auc:0.96466
# [1850]	validation-auc:0.96509
# [1900]	validation-auc:0.96545
# [1950]	validation-auc:0.96567
# [2000]	validation-auc:0.96601
# [2050]	validation-auc:0.96624
# [2100]	validation-auc:0.96653
# [2150]	validation-auc:0.96694
# [2200]	validation-auc:0.96714
# [2250]	validation-auc:0.96752
# [2300]	validation-auc:0.96775
# [2350]	validation-auc:0.96815
# [2400]	validation-auc:0.96856
# [2450]	validation-auc:0.96877
# [2500]	validation-auc:0.96919
# [2550]	validation-auc:0.96947
# [2600]	validation-auc:0.96968
# [2650]	validation-auc:0.96983
# [2700]	validation-auc:0.96993
# [2750]	validation-auc:0.97018
# [2800]	validation-auc:0.97034
# [2850]	validation-auc:0.97056
# [2900]	validation-auc:0.97077
# [2950]	validation-auc:0.97087
# [3000]	validation-auc:0.97117
# [3050]	validation-auc:0.97137
# [3100]	validation-auc:0.97158
# [3150]	validation-auc:0.97173
# [3200]	validation-auc:0.97194
# [3250]	validation-auc:0.97218
# [3300]	validation-auc:0.97235
# [3350]	validation-auc:0.97263
# [3400]	validation-auc:0.97278
# [3450]	validation-auc:0.97284
# [3500]	validation-auc:0.97295
# [3550]	validation-auc:0.97308
# [3600]	validation-auc:0.97321
# [3650]	validation-auc:0.97330
# [3700]	validation-auc:0.97341
# [3750]	validation-auc:0.97347
# [3800]	validation-auc:0.97363
# [3850]	validation-auc:0.97371
# [3900]	validation-auc:0.97375
# [3950]	validation-auc:0.97382
# [3976]	validation-auc:0.97383
#  Fold 1 AUC-ROC : 0.9738 | Best Iteration: 3927
#    Accuracy     : 0.9884
#    Precision_0  : 0.9889 | Precision_1 : 0.9700
#    Recall_0     : 0.9992 | Recall_1    : 0.6893
#    F1 Score_0   : 0.9940 | F1 Score_1  : 0.8059
#
#  Fold 2
# [0]	validation-auc:0.78069
# [50]	validation-auc:0.88839
# [100]	validation-auc:0.90902
# [150]	validation-auc:0.91809
# [200]	validation-auc:0.92439
# [250]	validation-auc:0.92796
# [300]	validation-auc:0.93192
# [350]	validation-auc:0.93545
# [400]	validation-auc:0.93815
# [450]	validation-auc:0.94069
# [500]	validation-auc:0.94186
# [550]	validation-auc:0.94374
# [600]	validation-auc:0.94566
# [650]	validation-auc:0.94745
# [700]	validation-auc:0.94841
# [750]	validation-auc:0.94985
# [800]	validation-auc:0.95106
# [850]	validation-auc:0.95214
# [900]	validation-auc:0.95333
# [950]	validation-auc:0.95455
# [1000]	validation-auc:0.95550
# [1050]	validation-auc:0.95656
# [1100]	validation-auc:0.95730
# [1150]	validation-auc:0.95818
# [1200]	validation-auc:0.95894
# [1250]	validation-auc:0.95974
# [1300]	validation-auc:0.96062
# [1350]	validation-auc:0.96135
# [1400]	validation-auc:0.96186
# [1450]	validation-auc:0.96249
# [1500]	validation-auc:0.96317
# [1550]	validation-auc:0.96356
# [1600]	validation-auc:0.96407
# [1650]	validation-auc:0.96437
# [1700]	validation-auc:0.96470
# [1750]	validation-auc:0.96518
# [1800]	validation-auc:0.96559
# [1850]	validation-auc:0.96599
# [1900]	validation-auc:0.96631
# [1950]	validation-auc:0.96670
# [2000]	validation-auc:0.96696
# [2050]	validation-auc:0.96740
# [2100]	validation-auc:0.96766
# [2150]	validation-auc:0.96793
# [2200]	validation-auc:0.96813
# [2250]	validation-auc:0.96834
# [2300]	validation-auc:0.96861
# [2350]	validation-auc:0.96867
# [2400]	validation-auc:0.96890
# [2450]	validation-auc:0.96914
# [2500]	validation-auc:0.96944
# [2550]	validation-auc:0.96958
# [2600]	validation-auc:0.96976
# [2650]	validation-auc:0.96992
# [2700]	validation-auc:0.97010
# [2750]	validation-auc:0.97019
# [2800]	validation-auc:0.97038
# [2850]	validation-auc:0.97058
# [2900]	validation-auc:0.97071
# [2950]	validation-auc:0.97091
# [3000]	validation-auc:0.97105
# [3050]	validation-auc:0.97109
# [3060]	validation-auc:0.97110
#  Fold 2 AUC-ROC : 0.9711 | Best Iteration: 3011
#    Accuracy     : 0.9866
#    Precision_0  : 0.9873 | Precision_1 : 0.9550
#    Recall_0     : 0.9989 | Recall_1    : 0.6467
#    F1 Score_0   : 0.9931 | F1 Score_1  : 0.7711
#
#  Fold 3
# [0]	validation-auc:0.79066
# [50]	validation-auc:0.89475
# [100]	validation-auc:0.91429
# [150]	validation-auc:0.92379
# [200]	validation-auc:0.93013
# [250]	validation-auc:0.93445
# [300]	validation-auc:0.93878
# [350]	validation-auc:0.94203
# [400]	validation-auc:0.94467
# [450]	validation-auc:0.94720
# [500]	validation-auc:0.94896
# [550]	validation-auc:0.95073
# [600]	validation-auc:0.95251
# [650]	validation-auc:0.95441
# [700]	validation-auc:0.95572
# [750]	validation-auc:0.95690
# [800]	validation-auc:0.95817
# [850]	validation-auc:0.95940
# [900]	validation-auc:0.96041
# [950]	validation-auc:0.96153
# [1000]	validation-auc:0.96240
# [1050]	validation-auc:0.96367
# [1100]	validation-auc:0.96439
# [1150]	validation-auc:0.96515
# [1200]	validation-auc:0.96593
# [1250]	validation-auc:0.96634
# [1300]	validation-auc:0.96704
# [1350]	validation-auc:0.96774
# [1400]	validation-auc:0.96830
# [1450]	validation-auc:0.96867
# [1500]	validation-auc:0.96915
# [1550]	validation-auc:0.96962
# [1600]	validation-auc:0.97001
# [1650]	validation-auc:0.97052
# [1700]	validation-auc:0.97095
# [1750]	validation-auc:0.97131
# [1800]	validation-auc:0.97169
# [1850]	validation-auc:0.97195
# [1900]	validation-auc:0.97232
# [1950]	validation-auc:0.97265
# [2000]	validation-auc:0.97280
# [2050]	validation-auc:0.97311
# [2100]	validation-auc:0.97315
# [2150]	validation-auc:0.97346
# [2200]	validation-auc:0.97379
# [2250]	validation-auc:0.97388
# [2272]	validation-auc:0.97387
#  Fold 3 AUC-ROC : 0.9740 | Best Iteration: 2223
#    Accuracy     : 0.9866
#    Precision_0  : 0.9872 | Precision_1 : 0.9603
#    Recall_0     : 0.9990 | Recall_1    : 0.6433
#    F1 Score_0   : 0.9931 | F1 Score_1  : 0.7704
#
#  Fold 4
# [0]	validation-auc:0.75502
# [50]	validation-auc:0.88330
# [100]	validation-auc:0.90271
# [150]	validation-auc:0.91361
# [200]	validation-auc:0.91911
# [250]	validation-auc:0.92420
# [300]	validation-auc:0.92769
# [350]	validation-auc:0.93119
# [400]	validation-auc:0.93427
# [450]	validation-auc:0.93633
# [500]	validation-auc:0.93869
# [550]	validation-auc:0.94071
# [600]	validation-auc:0.94248
# [650]	validation-auc:0.94419
# [700]	validation-auc:0.94554
# [750]	validation-auc:0.94723
# [800]	validation-auc:0.94835
# [850]	validation-auc:0.94977
# [900]	validation-auc:0.95120
# [950]	validation-auc:0.95235
# [1000]	validation-auc:0.95316
# [1050]	validation-auc:0.95414
# [1100]	validation-auc:0.95519
# [1150]	validation-auc:0.95594
# [1200]	validation-auc:0.95680
# [1250]	validation-auc:0.95742
# [1300]	validation-auc:0.95809
# [1350]	validation-auc:0.95889
# [1400]	validation-auc:0.95936
# [1450]	validation-auc:0.96003
# [1500]	validation-auc:0.96044
# [1550]	validation-auc:0.96123
# [1600]	validation-auc:0.96182
# [1650]	validation-auc:0.96239
# [1700]	validation-auc:0.96276
# [1750]	validation-auc:0.96333
# [1800]	validation-auc:0.96382
# [1850]	validation-auc:0.96412
# [1900]	validation-auc:0.96454
# [1950]	validation-auc:0.96492
# [2000]	validation-auc:0.96523
# [2050]	validation-auc:0.96561
# [2100]	validation-auc:0.96589
# [2150]	validation-auc:0.96610
# [2200]	validation-auc:0.96629
# [2250]	validation-auc:0.96657
# [2300]	validation-auc:0.96682
# [2350]	validation-auc:0.96705
# [2400]	validation-auc:0.96729
# [2450]	validation-auc:0.96755
# [2500]	validation-auc:0.96777
# [2550]	validation-auc:0.96797
# [2600]	validation-auc:0.96828
# [2650]	validation-auc:0.96854
# [2700]	validation-auc:0.96870
# [2750]	validation-auc:0.96886
# [2800]	validation-auc:0.96903
# [2850]	validation-auc:0.96911
# [2900]	validation-auc:0.96934
# [2950]	validation-auc:0.96958
# [3000]	validation-auc:0.96964
# [3043]	validation-auc:0.96957
#  Fold 4 AUC-ROC : 0.9697 | Best Iteration: 2993
#    Accuracy     : 0.9868
#    Precision_0  : 0.9873 | Precision_1 : 0.9666
#    Recall_0     : 0.9992 | Recall_1    : 0.6447
#    F1 Score_0   : 0.9932 | F1 Score_1  : 0.7735
#
#  Fold 5
# [0]	validation-auc:0.77848
# [50]	validation-auc:0.88093
# [100]	validation-auc:0.89983
# [150]	validation-auc:0.90971
# [200]	validation-auc:0.91660
# [250]	validation-auc:0.92219
# [300]	validation-auc:0.92673
# [350]	validation-auc:0.92976
# [400]	validation-auc:0.93305
# [450]	validation-auc:0.93547
# [500]	validation-auc:0.93816
# [550]	validation-auc:0.94030
# [600]	validation-auc:0.94230
# [650]	validation-auc:0.94421
# [700]	validation-auc:0.94601
# [750]	validation-auc:0.94813
# [800]	validation-auc:0.94927
# [850]	validation-auc:0.95045
# [900]	validation-auc:0.95181
# [950]	validation-auc:0.95302
# [1000]	validation-auc:0.95406
# [1050]	validation-auc:0.95505
# [1100]	validation-auc:0.95593
# [1150]	validation-auc:0.95678
# [1200]	validation-auc:0.95766
# [1250]	validation-auc:0.95843
# [1300]	validation-auc:0.95920
# [1350]	validation-auc:0.95987
# [1400]	validation-auc:0.96053
# [1450]	validation-auc:0.96093
# [1500]	validation-auc:0.96144
# [1550]	validation-auc:0.96201
# [1600]	validation-auc:0.96257
# [1650]	validation-auc:0.96312
# [1700]	validation-auc:0.96353
# [1750]	validation-auc:0.96382
# [1800]	validation-auc:0.96427
# [1850]	validation-auc:0.96468
# [1900]	validation-auc:0.96503
# [1950]	validation-auc:0.96535
# [2000]	validation-auc:0.96570
# [2050]	validation-auc:0.96602
# [2100]	validation-auc:0.96638
# [2150]	validation-auc:0.96662
# [2200]	validation-auc:0.96692
# [2250]	validation-auc:0.96713
# [2300]	validation-auc:0.96732
# [2350]	validation-auc:0.96761
# [2400]	validation-auc:0.96785
# [2450]	validation-auc:0.96810
# [2500]	validation-auc:0.96824
# [2550]	validation-auc:0.96840
# [2600]	validation-auc:0.96864
# [2650]	validation-auc:0.96881
# [2700]	validation-auc:0.96894
# [2750]	validation-auc:0.96909
# [2800]	validation-auc:0.96916
# [2850]	validation-auc:0.96937
# [2900]	validation-auc:0.96951
# [2950]	validation-auc:0.96969
# [3000]	validation-auc:0.96986
# [3050]	validation-auc:0.97008
# [3100]	validation-auc:0.97017
# [3150]	validation-auc:0.97029
# [3200]	validation-auc:0.97038
# [3250]	validation-auc:0.97050
# [3300]	validation-auc:0.97058
# [3350]	validation-auc:0.97072
# [3400]	validation-auc:0.97085
# [3450]	validation-auc:0.97097
# [3500]	validation-auc:0.97106
# [3550]	validation-auc:0.97109
# [3600]	validation-auc:0.97115
# [3650]	validation-auc:0.97129
# [3700]	validation-auc:0.97137
# [3750]	validation-auc:0.97147
# [3800]	validation-auc:0.97154
# [3850]	validation-auc:0.97158
# [3900]	validation-auc:0.97160
# [3941]	validation-auc:0.97165
#  Fold 5 AUC-ROC : 0.9716 | Best Iteration: 3891
#    Accuracy     : 0.9877
#    Precision_0  : 0.9883 | Precision_1 : 0.9626
#    Recall_0     : 0.9991 | Recall_1    : 0.6733
#    F1 Score_0   : 0.9936 | F1 Score_1  : 0.7924
#
#  Fold 6
# [0]	validation-auc:0.78485
# [50]	validation-auc:0.88786
# [100]	validation-auc:0.90589
# [150]	validation-auc:0.91605
# [200]	validation-auc:0.92070
# [250]	validation-auc:0.92485
# [300]	validation-auc:0.93001
# [350]	validation-auc:0.93336
# [400]	validation-auc:0.93559
# [450]	validation-auc:0.93825
# [500]	validation-auc:0.94038
# [550]	validation-auc:0.94254
# [600]	validation-auc:0.94437
# [650]	validation-auc:0.94566
# [700]	validation-auc:0.94687
# [750]	validation-auc:0.94848
# [800]	validation-auc:0.94998
# [850]	validation-auc:0.95124
# [900]	validation-auc:0.95244
# [950]	validation-auc:0.95361
# [1000]	validation-auc:0.95471
# [1050]	validation-auc:0.95581
# [1100]	validation-auc:0.95669
# [1150]	validation-auc:0.95761
# [1200]	validation-auc:0.95843
# [1250]	validation-auc:0.95940
# [1300]	validation-auc:0.95992
# [1350]	validation-auc:0.96060
# [1400]	validation-auc:0.96141
# [1450]	validation-auc:0.96194
# [1500]	validation-auc:0.96251
# [1550]	validation-auc:0.96330
# [1600]	validation-auc:0.96372
# [1650]	validation-auc:0.96420
# [1700]	validation-auc:0.96491
# [1750]	validation-auc:0.96542
# [1800]	validation-auc:0.96589
# [1850]	validation-auc:0.96639
# [1900]	validation-auc:0.96673
# [1950]	validation-auc:0.96710
# [2000]	validation-auc:0.96746
# [2050]	validation-auc:0.96782
# [2100]	validation-auc:0.96812
# [2150]	validation-auc:0.96841
# [2200]	validation-auc:0.96881
# [2250]	validation-auc:0.96913
# [2300]	validation-auc:0.96944
# [2350]	validation-auc:0.96978
# [2400]	validation-auc:0.97003
# [2450]	validation-auc:0.97020
# [2500]	validation-auc:0.97043
# [2550]	validation-auc:0.97070
# [2600]	validation-auc:0.97102
# [2650]	validation-auc:0.97121
# [2700]	validation-auc:0.97152
# [2750]	validation-auc:0.97169
# [2800]	validation-auc:0.97186
# [2850]	validation-auc:0.97206
# [2900]	validation-auc:0.97230
# [2950]	validation-auc:0.97237
# [3000]	validation-auc:0.97247
# [3050]	validation-auc:0.97267
# [3100]	validation-auc:0.97293
# [3150]	validation-auc:0.97309
# [3200]	validation-auc:0.97327
# [3250]	validation-auc:0.97345
# [3300]	validation-auc:0.97358
# [3350]	validation-auc:0.97377
# [3400]	validation-auc:0.97391
# [3450]	validation-auc:0.97407
# [3500]	validation-auc:0.97417
# [3550]	validation-auc:0.97438
# [3600]	validation-auc:0.97457
# [3650]	validation-auc:0.97468
# [3700]	validation-auc:0.97470
# [3705]	validation-auc:0.97472
#  Fold 6 AUC-ROC : 0.9747 | Best Iteration: 3655
#    Accuracy     : 0.9880
#    Precision_0  : 0.9888 | Precision_1 : 0.9588
#    Recall_0     : 0.9989 | Recall_1    : 0.6873
#    F1 Score_0   : 0.9938 | F1 Score_1  : 0.8007
#
#  Fold 7
# [0]	validation-auc:0.78225
# [50]	validation-auc:0.89020
# [100]	validation-auc:0.90805
# [150]	validation-auc:0.91733
# [200]	validation-auc:0.92225
# [250]	validation-auc:0.92705
# [300]	validation-auc:0.93059
# [350]	validation-auc:0.93371
# [400]	validation-auc:0.93613
# [450]	validation-auc:0.93853
# [500]	validation-auc:0.94127
# [550]	validation-auc:0.94335
# [600]	validation-auc:0.94524
# [650]	validation-auc:0.94668
# [700]	validation-auc:0.94817
# [750]	validation-auc:0.95000
# [800]	validation-auc:0.95156
# [850]	validation-auc:0.95286
# [900]	validation-auc:0.95376
# [950]	validation-auc:0.95499
# [1000]	validation-auc:0.95612
# [1050]	validation-auc:0.95714
# [1100]	validation-auc:0.95802
# [1150]	validation-auc:0.95902
# [1200]	validation-auc:0.95964
# [1250]	validation-auc:0.96024
# [1300]	validation-auc:0.96097
# [1350]	validation-auc:0.96159
# [1400]	validation-auc:0.96220
# [1450]	validation-auc:0.96274
# [1500]	validation-auc:0.96362
# [1550]	validation-auc:0.96416
# [1600]	validation-auc:0.96459
# [1650]	validation-auc:0.96507
# [1700]	validation-auc:0.96578
# [1750]	validation-auc:0.96625
# [1800]	validation-auc:0.96660
# [1850]	validation-auc:0.96692
# [1900]	validation-auc:0.96731
# [1950]	validation-auc:0.96755
# [2000]	validation-auc:0.96791
# [2050]	validation-auc:0.96816
# [2100]	validation-auc:0.96845
# [2150]	validation-auc:0.96869
# [2200]	validation-auc:0.96905
# [2250]	validation-auc:0.96936
# [2300]	validation-auc:0.96967
# [2350]	validation-auc:0.96982
# [2400]	validation-auc:0.96995
# [2450]	validation-auc:0.97009
# [2500]	validation-auc:0.97011
# [2550]	validation-auc:0.97018
# [2600]	validation-auc:0.97026
# [2650]	validation-auc:0.97041
# [2700]	validation-auc:0.97071
# [2750]	validation-auc:0.97094
# [2800]	validation-auc:0.97118
# [2850]	validation-auc:0.97130
# [2900]	validation-auc:0.97135
# [2950]	validation-auc:0.97149
# [3000]	validation-auc:0.97161
# [3050]	validation-auc:0.97175
# [3100]	validation-auc:0.97192
# [3150]	validation-auc:0.97197
# [3200]	validation-auc:0.97207
# [3250]	validation-auc:0.97227
# [3300]	validation-auc:0.97241
# [3350]	validation-auc:0.97260
# [3400]	validation-auc:0.97278
# [3450]	validation-auc:0.97280
# [3500]	validation-auc:0.97291
# [3550]	validation-auc:0.97306
# [3600]	validation-auc:0.97315
# [3650]	validation-auc:0.97325
# [3700]	validation-auc:0.97341
# [3750]	validation-auc:0.97358
# [3800]	validation-auc:0.97360
# [3850]	validation-auc:0.97363
# [3900]	validation-auc:0.97377
# [3950]	validation-auc:0.97383
# [4000]	validation-auc:0.97390
# [4050]	validation-auc:0.97403
# [4100]	validation-auc:0.97414
# [4150]	validation-auc:0.97424
# [4200]	validation-auc:0.97434
# [4250]	validation-auc:0.97433
# [4251]	validation-auc:0.97433
#  Fold 7 AUC-ROC : 0.9743 | Best Iteration: 4201
#    Accuracy     : 0.9877
#    Precision_0  : 0.9882 | Precision_1 : 0.9659
#    Recall_0     : 0.9991 | Recall_1    : 0.6718
#    F1 Score_0   : 0.9937 | F1 Score_1  : 0.7925
#
#  Fold 8
# [0]	validation-auc:0.78224
# [50]	validation-auc:0.88526
# [100]	validation-auc:0.90173
# [150]	validation-auc:0.91241
# [200]	validation-auc:0.91764
# [250]	validation-auc:0.92285
# [300]	validation-auc:0.92773
# [350]	validation-auc:0.93153
# [400]	validation-auc:0.93424
# [450]	validation-auc:0.93677
# [500]	validation-auc:0.93947
# [550]	validation-auc:0.94125
# [600]	validation-auc:0.94335
# [650]	validation-auc:0.94557
# [700]	validation-auc:0.94790
# [750]	validation-auc:0.94932
# [800]	validation-auc:0.95103
# [850]	validation-auc:0.95246
# [900]	validation-auc:0.95368
# [950]	validation-auc:0.95551
# [1000]	validation-auc:0.95652
# [1050]	validation-auc:0.95744
# [1100]	validation-auc:0.95834
# [1150]	validation-auc:0.95926
# [1200]	validation-auc:0.96021
# [1250]	validation-auc:0.96127
# [1300]	validation-auc:0.96182
# [1350]	validation-auc:0.96241
# [1400]	validation-auc:0.96311
# [1450]	validation-auc:0.96363
# [1500]	validation-auc:0.96434
# [1550]	validation-auc:0.96517
# [1600]	validation-auc:0.96584
# [1650]	validation-auc:0.96659
# [1700]	validation-auc:0.96716
# [1750]	validation-auc:0.96767
# [1800]	validation-auc:0.96820
# [1850]	validation-auc:0.96867
# [1900]	validation-auc:0.96901
# [1950]	validation-auc:0.96941
# [2000]	validation-auc:0.96996
# [2050]	validation-auc:0.97037
# [2100]	validation-auc:0.97067
# [2150]	validation-auc:0.97091
# [2200]	validation-auc:0.97125
# [2250]	validation-auc:0.97164
# [2300]	validation-auc:0.97198
# [2350]	validation-auc:0.97210
# [2400]	validation-auc:0.97240
# [2450]	validation-auc:0.97266
# [2500]	validation-auc:0.97293
# [2550]	validation-auc:0.97316
# [2600]	validation-auc:0.97346
# [2650]	validation-auc:0.97363
# [2700]	validation-auc:0.97378
# [2750]	validation-auc:0.97395
# [2800]	validation-auc:0.97420
# [2850]	validation-auc:0.97436
# [2900]	validation-auc:0.97461
# [2950]	validation-auc:0.97489
# [3000]	validation-auc:0.97506
# [3050]	validation-auc:0.97521
# [3100]	validation-auc:0.97546
# [3150]	validation-auc:0.97562
# [3200]	validation-auc:0.97572
# [3250]	validation-auc:0.97579
# [3300]	validation-auc:0.97589
# [3350]	validation-auc:0.97595
# [3400]	validation-auc:0.97612
# [3450]	validation-auc:0.97627
# [3500]	validation-auc:0.97646
# [3550]	validation-auc:0.97650
# [3600]	validation-auc:0.97659
# [3650]	validation-auc:0.97666
# [3700]	validation-auc:0.97676
# [3750]	validation-auc:0.97686
# [3800]	validation-auc:0.97696
# [3850]	validation-auc:0.97709
# [3889]	validation-auc:0.97703
#  Fold 8 AUC-ROC : 0.9771 | Best Iteration: 3840
#    Accuracy     : 0.9878
#    Precision_0  : 0.9882 | Precision_1 : 0.9720
#    Recall_0     : 0.9993 | Recall_1    : 0.6715
#    F1 Score_0   : 0.9937 | F1 Score_1  : 0.7943
#
#  Fold 9
# [0]	validation-auc:0.77549
# [50]	validation-auc:0.88238
# [100]	validation-auc:0.90292
# [150]	validation-auc:0.91325
# [200]	validation-auc:0.91949
# [250]	validation-auc:0.92464
# [300]	validation-auc:0.92790
# [350]	validation-auc:0.93074
# [400]	validation-auc:0.93330
# [450]	validation-auc:0.93556
# [500]	validation-auc:0.93771
# [550]	validation-auc:0.93971
# [600]	validation-auc:0.94164
# [650]	validation-auc:0.94318
# [700]	validation-auc:0.94470
# [750]	validation-auc:0.94667
# [800]	validation-auc:0.94792
# [850]	validation-auc:0.94956
# [900]	validation-auc:0.95050
# [950]	validation-auc:0.95172
# [1000]	validation-auc:0.95293
# [1050]	validation-auc:0.95371
# [1100]	validation-auc:0.95463
# [1150]	validation-auc:0.95529
# [1200]	validation-auc:0.95619
# [1250]	validation-auc:0.95694
# [1300]	validation-auc:0.95763
# [1350]	validation-auc:0.95818
# [1400]	validation-auc:0.95898
# [1450]	validation-auc:0.95947
# [1500]	validation-auc:0.96040
# [1550]	validation-auc:0.96096
# [1600]	validation-auc:0.96153
# [1650]	validation-auc:0.96222
# [1700]	validation-auc:0.96274
# [1750]	validation-auc:0.96307
# [1800]	validation-auc:0.96365
# [1850]	validation-auc:0.96400
# [1900]	validation-auc:0.96437
# [1950]	validation-auc:0.96486
# [2000]	validation-auc:0.96519
# [2050]	validation-auc:0.96559
# [2100]	validation-auc:0.96595
# [2150]	validation-auc:0.96626
# [2200]	validation-auc:0.96651
# [2250]	validation-auc:0.96696
# [2300]	validation-auc:0.96716
# [2350]	validation-auc:0.96736
# [2400]	validation-auc:0.96777
# [2450]	validation-auc:0.96792
# [2500]	validation-auc:0.96822
# [2550]	validation-auc:0.96849
# [2600]	validation-auc:0.96873
# [2650]	validation-auc:0.96904
# [2700]	validation-auc:0.96925
# [2750]	validation-auc:0.96951
# [2800]	validation-auc:0.96983
# [2850]	validation-auc:0.97016
# [2900]	validation-auc:0.97052
# [2950]	validation-auc:0.97062
# [3000]	validation-auc:0.97079
# [3050]	validation-auc:0.97094
# [3100]	validation-auc:0.97118
# [3150]	validation-auc:0.97135
# [3200]	validation-auc:0.97158
# [3250]	validation-auc:0.97181
# [3300]	validation-auc:0.97196
# [3350]	validation-auc:0.97207
# [3400]	validation-auc:0.97219
# [3450]	validation-auc:0.97230
# [3500]	validation-auc:0.97247
# [3550]	validation-auc:0.97254
# [3600]	validation-auc:0.97264
# [3650]	validation-auc:0.97269
# [3700]	validation-auc:0.97279
# [3750]	validation-auc:0.97289
# [3800]	validation-auc:0.97304
# [3850]	validation-auc:0.97325
# [3900]	validation-auc:0.97346
# [3950]	validation-auc:0.97358
# [4000]	validation-auc:0.97369
# [4050]	validation-auc:0.97376
# [4100]	validation-auc:0.97377
# [4150]	validation-auc:0.97379
# [4200]	validation-auc:0.97390
# [4250]	validation-auc:0.97405
# [4300]	validation-auc:0.97417
# [4350]	validation-auc:0.97422
# [4400]	validation-auc:0.97423
# [4450]	validation-auc:0.97426
# [4500]	validation-auc:0.97432
# [4550]	validation-auc:0.97435
# [4600]	validation-auc:0.97441
# [4650]	validation-auc:0.97446
# [4700]	validation-auc:0.97451
# [4750]	validation-auc:0.97455
# [4800]	validation-auc:0.97465
# [4850]	validation-auc:0.97476
# [4900]	validation-auc:0.97485
# [4950]	validation-auc:0.97488
# [4999]	validation-auc:0.97488
#  Fold 9 AUC-ROC : 0.9749 | Best Iteration: 4973
#    Accuracy     : 0.9873
#    Precision_0  : 0.9880 | Precision_1 : 0.9615
#    Recall_0     : 0.9990 | Recall_1    : 0.6642
#    F1 Score_0   : 0.9935 | F1 Score_1  : 0.7857
#
#  Fold 10
# [0]	validation-auc:0.78183
# [50]	validation-auc:0.89204
# [100]	validation-auc:0.90963
# [150]	validation-auc:0.92076
# [200]	validation-auc:0.92739
# [250]	validation-auc:0.93204
# [300]	validation-auc:0.93527
# [350]	validation-auc:0.93818
# [400]	validation-auc:0.94063
# [450]	validation-auc:0.94296
# [500]	validation-auc:0.94551
# [550]	validation-auc:0.94722
# [600]	validation-auc:0.94939
# [650]	validation-auc:0.95115
# [700]	validation-auc:0.95252
# [750]	validation-auc:0.95399
# [800]	validation-auc:0.95515
# [850]	validation-auc:0.95664
# [900]	validation-auc:0.95760
# [950]	validation-auc:0.95868
# [1000]	validation-auc:0.95988
# [1050]	validation-auc:0.96065
# [1100]	validation-auc:0.96153
# [1150]	validation-auc:0.96236
# [1200]	validation-auc:0.96311
# [1250]	validation-auc:0.96397
# [1300]	validation-auc:0.96477
# [1350]	validation-auc:0.96547
# [1400]	validation-auc:0.96610
# [1450]	validation-auc:0.96662
# [1500]	validation-auc:0.96721
# [1550]	validation-auc:0.96770
# [1600]	validation-auc:0.96820
# [1650]	validation-auc:0.96867
# [1700]	validation-auc:0.96920
# [1750]	validation-auc:0.96961
# [1800]	validation-auc:0.97007
# [1850]	validation-auc:0.97050
# [1900]	validation-auc:0.97096
# [1950]	validation-auc:0.97129
# [2000]	validation-auc:0.97159
# [2050]	validation-auc:0.97200
# [2100]	validation-auc:0.97220
# [2150]	validation-auc:0.97259
# [2200]	validation-auc:0.97285
# [2250]	validation-auc:0.97303
# [2300]	validation-auc:0.97314
# [2350]	validation-auc:0.97339
# [2400]	validation-auc:0.97363
# [2450]	validation-auc:0.97379
# [2500]	validation-auc:0.97404
# [2550]	validation-auc:0.97422
# [2600]	validation-auc:0.97439
# [2650]	validation-auc:0.97460
# [2700]	validation-auc:0.97481
# [2750]	validation-auc:0.97503
# [2800]	validation-auc:0.97526
# [2850]	validation-auc:0.97543
# [2900]	validation-auc:0.97556
# [2950]	validation-auc:0.97578
# [3000]	validation-auc:0.97589
# [3050]	validation-auc:0.97601
# [3100]	validation-auc:0.97609
# [3150]	validation-auc:0.97626
# [3200]	validation-auc:0.97641
# [3250]	validation-auc:0.97655
# [3300]	validation-auc:0.97656
# [3350]	validation-auc:0.97665
# [3400]	validation-auc:0.97676
# [3450]	validation-auc:0.97681
# [3500]	validation-auc:0.97689
# [3550]	validation-auc:0.97693
# [3600]	validation-auc:0.97708
# [3650]	validation-auc:0.97713
# [3700]	validation-auc:0.97720
# [3750]	validation-auc:0.97727
# [3800]	validation-auc:0.97737
# [3850]	validation-auc:0.97741
# [3900]	validation-auc:0.97748
# [3950]	validation-auc:0.97753
# [4000]	validation-auc:0.97755
# [4050]	validation-auc:0.97766
# [4100]	validation-auc:0.97770
# [4115]	validation-auc:0.97770
#  Fold 10 AUC-ROC : 0.9777 | Best Iteration: 4065
#    Accuracy     : 0.9880
#    Precision_0  : 0.9884 | Precision_1 : 0.9709
#    Recall_0     : 0.9993 | Recall_1    : 0.6778
#    F1 Score_0   : 0.9938 | F1 Score_1  : 0.7983
#
#  Cross-Validation Summary (XGBoost + Label Encoding + Scaling)
# Fold 1: AUC=0.9738 | Acc=0.9884 | Prec_0=0.9889 | Prec_1=0.9700 | Recall_0=0.9992 | Recall_1=0.6893 | F1_0=0.9940 | F1_1=0.8059
# Fold 2: AUC=0.9711 | Acc=0.9866 | Prec_0=0.9873 | Prec_1=0.9550 | Recall_0=0.9989 | Recall_1=0.6467 | F1_0=0.9931 | F1_1=0.7711
# Fold 3: AUC=0.9740 | Acc=0.9866 | Prec_0=0.9872 | Prec_1=0.9603 | Recall_0=0.9990 | Recall_1=0.6433 | F1_0=0.9931 | F1_1=0.7704
# Fold 4: AUC=0.9697 | Acc=0.9868 | Prec_0=0.9873 | Prec_1=0.9666 | Recall_0=0.9992 | Recall_1=0.6447 | F1_0=0.9932 | F1_1=0.7735
# Fold 5: AUC=0.9716 | Acc=0.9877 | Prec_0=0.9883 | Prec_1=0.9626 | Recall_0=0.9991 | Recall_1=0.6733 | F1_0=0.9936 | F1_1=0.7924
# Fold 6: AUC=0.9747 | Acc=0.9880 | Prec_0=0.9888 | Prec_1=0.9588 | Recall_0=0.9989 | Recall_1=0.6873 | F1_0=0.9938 | F1_1=0.8007
# Fold 7: AUC=0.9743 | Acc=0.9877 | Prec_0=0.9882 | Prec_1=0.9659 | Recall_0=0.9991 | Recall_1=0.6718 | F1_0=0.9937 | F1_1=0.7925
# Fold 8: AUC=0.9771 | Acc=0.9878 | Prec_0=0.9882 | Prec_1=0.9720 | Recall_0=0.9993 | Recall_1=0.6715 | F1_0=0.9937 | F1_1=0.7943
# Fold 9: AUC=0.9749 | Acc=0.9873 | Prec_0=0.9880 | Prec_1=0.9615 | Recall_0=0.9990 | Recall_1=0.6642 | F1_0=0.9935 | F1_1=0.7857
# Fold 10: AUC=0.9777 | Acc=0.9880 | Prec_0=0.9884 | Prec_1=0.9709 | Recall_0=0.9993 | Recall_1=0.6778 | F1_0=0.9938 | F1_1=0.7983
#
#  Final Averages:
# AUC-ROC     : 0.9739 ± 0.0024
# Accuracy    : 0.9875
# Precision_0 : 0.9881
# Precision_1 : 0.9644
# Recall_0    : 0.9991
# Recall_1    : 0.6670
# F1 Score_0  : 0.9936
# F1 Score_1  : 0.7885
