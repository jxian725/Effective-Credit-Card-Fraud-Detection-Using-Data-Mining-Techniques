# %%
import pandas as pd
import pickle

# Load train_dataset 
train_data = pd.read_csv('datasets/train_dataset.csv')

# Separate features and target
X = train_data.drop(['isFraud'], axis=1)
y = train_data['isFraud']

# Load the 10-fold indices
with open("10_fold_indices.pkl", "rb") as f:
    splits = pickle.load(f)

print(f"Loaded {len(splits)} folds.")
# Out:
# Loaded 10 folds.

# %%
import pandas as pd
import numpy as np
import lightgbm as lgb
from sklearn.metrics import (
    roc_auc_score, accuracy_score, precision_score, recall_score, f1_score
)
from sklearn.model_selection import StratifiedKFold
from category_encoders import TargetEncoder
import os
import pickle

# -------------------- LightGBM Parameters --------------------
params = {
    'objective': 'binary',
    'metric': 'auc',
    'boosting_type': 'gbdt',
    'verbosity': -1,
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9,
    'random_state': 42
}

# -------------------- Setup --------------------
auc_scores = []
accuracy_scores = []
recall_0, recall_1 = [], []
precision_0, precision_1 = [], []
f1_0, f1_1 = [], []
feature_importance_df = pd.DataFrame()

os.makedirs('models/lightgbm', exist_ok=True)
os.makedirs('feature_importance', exist_ok=True)

# Assume X and y are already loaded
categorical_cols = X.select_dtypes(include='object').columns.tolist()

# -------------------- Cross-Validation Loop --------------------
for fold, (train_idx, val_idx) in enumerate(splits, 1):
    print(f"\n Fold {fold}")

    X_train, X_val = X.iloc[train_idx].copy(), X.iloc[val_idx].copy()
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

    # Target Encoding
    encoder = TargetEncoder(cols=categorical_cols)
    X_train[categorical_cols] = encoder.fit_transform(X_train[categorical_cols], y_train)
    X_val[categorical_cols] = encoder.transform(X_val[categorical_cols])

    # LightGBM Dataset
    train_dataset = lgb.Dataset(X_train, label=y_train)
    val_dataset = lgb.Dataset(X_val, label=y_val)

    # Train
    model = lgb.train(
        params=params,
        train_set=train_dataset,
        valid_sets=[val_dataset],
        num_boost_round=5000,
        callbacks=[
            lgb.early_stopping(50),
            lgb.log_evaluation(50)
        ]
    )

    # Predict and Evaluate
    y_val_pred_prob = model.predict(X_val, num_iteration=model.best_iteration)
    y_val_pred = (y_val_pred_prob > 0.5).astype(int)

    auc = roc_auc_score(y_val, y_val_pred_prob)
    accuracy = accuracy_score(y_val, y_val_pred)
    precision = precision_score(y_val, y_val_pred, average=None, zero_division=0)
    recall = recall_score(y_val, y_val_pred, average=None)
    f1 = f1_score(y_val, y_val_pred, average=None)

    # Append metrics
    auc_scores.append(auc)
    accuracy_scores.append(accuracy)
    precision_0.append(precision[0])
    precision_1.append(precision[1])
    recall_0.append(recall[0])
    recall_1.append(recall[1])
    f1_0.append(f1[0])
    f1_1.append(f1[1])

    print(f" Fold {fold} AUC-ROC : {auc:.4f} | Best Iteration: {model.best_iteration}")
    print(f"   Accuracy    : {accuracy:.4f}")
    print(f"   Precision_0 : {precision[0]:.4f} | Precision_1 : {precision[1]:.4f}")
    print(f"   Recall_0    : {recall[0]:.4f} | Recall_1    : {recall[1]:.4f}")
    print(f"   F1 Score_0  : {f1[0]:.4f} | F1 Score_1  : {f1[1]:.4f}")

    # Save model
    model.save_model(f'models/lightgbm/fold_{fold}.txt')

    # Feature importance
    fold_importance = pd.DataFrame({
        'feature': model.feature_name(),
        f'fold_{fold}': model.feature_importance(importance_type='gain')
    })
    if feature_importance_df.empty:
        feature_importance_df = fold_importance
    else:
        feature_importance_df = feature_importance_df.merge(fold_importance, on='feature')

# -------------------- Final Summary --------------------
feature_importance_df['avg_importance'] = feature_importance_df.drop('feature', axis=1).mean(axis=1)
feature_importance_df.sort_values(by='avg_importance', ascending=False, inplace=True)
feature_importance_df.to_csv('feature_importance/lgbm_feature_importance_target_encoded.csv', index=False)

# Final metrics summary
print("\nCross-Validation Results (LightGBM)")
for i in range(len(auc_scores)):
    print(f"Fold {i+1}: AUC={auc_scores[i]:.4f} | Acc={accuracy_scores[i]:.4f} | "
          f"Prec_0={precision_0[i]:.4f} | Prec_1={precision_1[i]:.4f} | "
          f"Recall_0={recall_0[i]:.4f} | Recall_1={recall_1[i]:.4f} | "
          f"F1_0={f1_0[i]:.4f} | F1_1={f1_1[i]:.4f}")

print("\nFinal Averages:")
print(f"AUC-ROC      : {np.mean(auc_scores):.4f} ± {np.std(auc_scores):.4f}")
print(f"Accuracy     : {np.mean(accuracy_scores):.4f}")
print(f"Precision_0  : {np.mean(precision_0):.4f}")
print(f"Precision_1  : {np.mean(precision_1):.4f}")
print(f"Recall_0     : {np.mean(recall_0):.4f}")
print(f"Recall_1     : {np.mean(recall_1):.4f}")
print(f"F1 Score_0   : {np.mean(f1_0):.4f}")
print(f"F1 Score_1   : {np.mean(f1_1):.4f}")
# Out:
#  Fold 1
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's auc: 0.89871
# [100]	valid_0's auc: 0.917034
# [150]	valid_0's auc: 0.926482
# [200]	valid_0's auc: 0.931943
# [250]	valid_0's auc: 0.935693
# [300]	valid_0's auc: 0.939356
# [350]	valid_0's auc: 0.941742
# [400]	valid_0's auc: 0.943676
# [450]	valid_0's auc: 0.94557
# [500]	valid_0's auc: 0.947164
# [550]	valid_0's auc: 0.948031
# [600]	valid_0's auc: 0.949135
# [650]	valid_0's auc: 0.950437
# [700]	valid_0's auc: 0.951319
# [750]	valid_0's auc: 0.953254
# [800]	valid_0's auc: 0.954056
# [850]	valid_0's auc: 0.954745
# [900]	valid_0's auc: 0.955595
# [950]	valid_0's auc: 0.955958
# [1000]	valid_0's auc: 0.956342
# [1050]	valid_0's auc: 0.957228
# [1100]	valid_0's auc: 0.958175
# [1150]	valid_0's auc: 0.95858
# [1200]	valid_0's auc: 0.95911
# [1250]	valid_0's auc: 0.959645
# [1300]	valid_0's auc: 0.960064
# [1350]	valid_0's auc: 0.960573
# [1400]	valid_0's auc: 0.961007
# [1450]	valid_0's auc: 0.961381
# [1500]	valid_0's auc: 0.961895
# [1550]	valid_0's auc: 0.962117
# [1600]	valid_0's auc: 0.962525
# [1650]	valid_0's auc: 0.962871
# [1700]	valid_0's auc: 0.963191
# [1750]	valid_0's auc: 0.963489
# [1800]	valid_0's auc: 0.963732
# [1850]	valid_0's auc: 0.964049
# [1900]	valid_0's auc: 0.964355
# [1950]	valid_0's auc: 0.964565
# [2000]	valid_0's auc: 0.964854
# [2050]	valid_0's auc: 0.96507
# [2100]	valid_0's auc: 0.965322
# [2150]	valid_0's auc: 0.965477
# [2200]	valid_0's auc: 0.965609
# [2250]	valid_0's auc: 0.965779
# [2300]	valid_0's auc: 0.966019
# [2350]	valid_0's auc: 0.966223
# [2400]	valid_0's auc: 0.966514
# [2450]	valid_0's auc: 0.966877
# [2500]	valid_0's auc: 0.967058
# [2550]	valid_0's auc: 0.967268
# [2600]	valid_0's auc: 0.96742
# [2650]	valid_0's auc: 0.967482
# [2700]	valid_0's auc: 0.967702
# [2750]	valid_0's auc: 0.967922
# [2800]	valid_0's auc: 0.968264
# [2850]	valid_0's auc: 0.968472
# [2900]	valid_0's auc: 0.968581
# [2950]	valid_0's auc: 0.968693
# [3000]	valid_0's auc: 0.968972
# [3050]	valid_0's auc: 0.969238
# [3100]	valid_0's auc: 0.969439
# [3150]	valid_0's auc: 0.969549
# [3200]	valid_0's auc: 0.969606
# Early stopping, best iteration is:
# [3173]	valid_0's auc: 0.969641
#  Fold 1 AUC-ROC : 0.9696 | Best Iteration: 3173
#    Accuracy    : 0.9876
#    Precision_0 : 0.9882 | Precision_1 : 0.9652
#    Recall_0    : 0.9991 | Recall_1    : 0.6704
#    F1 Score_0  : 0.9936 | F1 Score_1  : 0.7912
#
#  Fold 2
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's auc: 0.899994
# [100]	valid_0's auc: 0.91841
# [150]	valid_0's auc: 0.926995
# [200]	valid_0's auc: 0.932463
# [250]	valid_0's auc: 0.935688
# [300]	valid_0's auc: 0.938537
# [350]	valid_0's auc: 0.942404
# [400]	valid_0's auc: 0.944844
# [450]	valid_0's auc: 0.946898
# [500]	valid_0's auc: 0.948338
# [550]	valid_0's auc: 0.949794
# [600]	valid_0's auc: 0.951751
# [650]	valid_0's auc: 0.952682
# [700]	valid_0's auc: 0.953957
# [750]	valid_0's auc: 0.954857
# [800]	valid_0's auc: 0.955381
# [850]	valid_0's auc: 0.956038
# [900]	valid_0's auc: 0.957045
# [950]	valid_0's auc: 0.957979
# [1000]	valid_0's auc: 0.959134
# [1050]	valid_0's auc: 0.95983
# [1100]	valid_0's auc: 0.960136
# [1150]	valid_0's auc: 0.960841
# [1200]	valid_0's auc: 0.96124
# [1250]	valid_0's auc: 0.961642
# [1300]	valid_0's auc: 0.961913
# [1350]	valid_0's auc: 0.962498
# [1400]	valid_0's auc: 0.962709
# [1450]	valid_0's auc: 0.963286
# [1500]	valid_0's auc: 0.963857
# [1550]	valid_0's auc: 0.964204
# [1600]	valid_0's auc: 0.964761
# [1650]	valid_0's auc: 0.965127
# [1700]	valid_0's auc: 0.965478
# [1750]	valid_0's auc: 0.965863
# [1800]	valid_0's auc: 0.96618
# [1850]	valid_0's auc: 0.966493
# [1900]	valid_0's auc: 0.966724
# [1950]	valid_0's auc: 0.967022
# [2000]	valid_0's auc: 0.967271
# [2050]	valid_0's auc: 0.967582
# [2100]	valid_0's auc: 0.967726
# [2150]	valid_0's auc: 0.967874
# [2200]	valid_0's auc: 0.968286
# [2250]	valid_0's auc: 0.968496
# [2300]	valid_0's auc: 0.968628
# [2350]	valid_0's auc: 0.968847
# [2400]	valid_0's auc: 0.968987
# [2450]	valid_0's auc: 0.969266
# [2500]	valid_0's auc: 0.969367
# Early stopping, best iteration is:
# [2482]	valid_0's auc: 0.969381
#  Fold 2 AUC-ROC : 0.9694 | Best Iteration: 2482
#    Accuracy    : 0.9866
#    Precision_0 : 0.9873 | Precision_1 : 0.9570
#    Recall_0    : 0.9989 | Recall_1    : 0.6457
#    F1 Score_0  : 0.9931 | F1 Score_1  : 0.7711
#
#  Fold 3
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's auc: 0.904386
# [100]	valid_0's auc: 0.923314
# [150]	valid_0's auc: 0.931989
# [200]	valid_0's auc: 0.939318
# [250]	valid_0's auc: 0.942726
# [300]	valid_0's auc: 0.945089
# [350]	valid_0's auc: 0.947238
# [400]	valid_0's auc: 0.948354
# [450]	valid_0's auc: 0.950823
# [500]	valid_0's auc: 0.952543
# [550]	valid_0's auc: 0.953958
# [600]	valid_0's auc: 0.955214
# [650]	valid_0's auc: 0.956488
# [700]	valid_0's auc: 0.957446
# [750]	valid_0's auc: 0.958911
# [800]	valid_0's auc: 0.959715
# [850]	valid_0's auc: 0.960651
# [900]	valid_0's auc: 0.961388
# [950]	valid_0's auc: 0.961844
# [1000]	valid_0's auc: 0.962617
# [1050]	valid_0's auc: 0.963146
# [1100]	valid_0's auc: 0.963809
# [1150]	valid_0's auc: 0.964081
# [1200]	valid_0's auc: 0.964625
# [1250]	valid_0's auc: 0.965286
# [1300]	valid_0's auc: 0.965753
# [1350]	valid_0's auc: 0.96608
# [1400]	valid_0's auc: 0.966565
# [1450]	valid_0's auc: 0.966919
# [1500]	valid_0's auc: 0.967305
# [1550]	valid_0's auc: 0.967675
# [1600]	valid_0's auc: 0.968013
# [1650]	valid_0's auc: 0.968227
# [1700]	valid_0's auc: 0.968532
# [1750]	valid_0's auc: 0.968837
# [1800]	valid_0's auc: 0.96908
# [1850]	valid_0's auc: 0.969233
# [1900]	valid_0's auc: 0.969648
# [1950]	valid_0's auc: 0.969915
# [2000]	valid_0's auc: 0.97017
# [2050]	valid_0's auc: 0.970572
# [2100]	valid_0's auc: 0.970885
# [2150]	valid_0's auc: 0.970985
# [2200]	valid_0's auc: 0.97136
# [2250]	valid_0's auc: 0.971503
# [2300]	valid_0's auc: 0.97176
# [2350]	valid_0's auc: 0.972025
# [2400]	valid_0's auc: 0.972301
# [2450]	valid_0's auc: 0.972557
# [2500]	valid_0's auc: 0.97277
# [2550]	valid_0's auc: 0.972864
# [2600]	valid_0's auc: 0.972907
# [2650]	valid_0's auc: 0.973078
# [2700]	valid_0's auc: 0.973307
# [2750]	valid_0's auc: 0.973448
# [2800]	valid_0's auc: 0.973599
# [2850]	valid_0's auc: 0.973649
# [2900]	valid_0's auc: 0.973707
# [2950]	valid_0's auc: 0.973797
# [3000]	valid_0's auc: 0.973932
# [3050]	valid_0's auc: 0.97393
# [3100]	valid_0's auc: 0.974171
# [3150]	valid_0's auc: 0.974312
# [3200]	valid_0's auc: 0.974355
# [3250]	valid_0's auc: 0.974539
# [3300]	valid_0's auc: 0.974737
# [3350]	valid_0's auc: 0.974826
# [3400]	valid_0's auc: 0.974951
# [3450]	valid_0's auc: 0.97498
# [3500]	valid_0's auc: 0.975067
# [3550]	valid_0's auc: 0.975196
# [3600]	valid_0's auc: 0.975224
# [3650]	valid_0's auc: 0.975299
# Early stopping, best iteration is:
# [3640]	valid_0's auc: 0.975327
#  Fold 3 AUC-ROC : 0.9753 | Best Iteration: 3640
#    Accuracy    : 0.9880
#    Precision_0 : 0.9884 | Precision_1 : 0.9729
#    Recall_0    : 0.9993 | Recall_1    : 0.6772
#    F1 Score_0  : 0.9938 | F1 Score_1  : 0.7985
#
#  Fold 4
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's auc: 0.893133
# [100]	valid_0's auc: 0.913922
# [150]	valid_0's auc: 0.923412
# [200]	valid_0's auc: 0.928567
# [250]	valid_0's auc: 0.932852
# [300]	valid_0's auc: 0.937082
# [350]	valid_0's auc: 0.939734
# [400]	valid_0's auc: 0.942764
# [450]	valid_0's auc: 0.944379
# [500]	valid_0's auc: 0.946107
# [550]	valid_0's auc: 0.94764
# [600]	valid_0's auc: 0.949332
# [650]	valid_0's auc: 0.95014
# [700]	valid_0's auc: 0.950987
# [750]	valid_0's auc: 0.952098
# [800]	valid_0's auc: 0.952865
# [850]	valid_0's auc: 0.953659
# [900]	valid_0's auc: 0.954738
# [950]	valid_0's auc: 0.955336
# [1000]	valid_0's auc: 0.956031
# [1050]	valid_0's auc: 0.956638
# [1100]	valid_0's auc: 0.957069
# [1150]	valid_0's auc: 0.957651
# [1200]	valid_0's auc: 0.958008
# [1250]	valid_0's auc: 0.958394
# [1300]	valid_0's auc: 0.958722
# [1350]	valid_0's auc: 0.959186
# [1400]	valid_0's auc: 0.959596
# [1450]	valid_0's auc: 0.960104
# [1500]	valid_0's auc: 0.960532
# [1550]	valid_0's auc: 0.960915
# [1600]	valid_0's auc: 0.961207
# [1650]	valid_0's auc: 0.961534
# [1700]	valid_0's auc: 0.961902
# [1750]	valid_0's auc: 0.962139
# [1800]	valid_0's auc: 0.962471
# [1850]	valid_0's auc: 0.962682
# [1900]	valid_0's auc: 0.962995
# [1950]	valid_0's auc: 0.963334
# [2000]	valid_0's auc: 0.96407
# [2050]	valid_0's auc: 0.964499
# [2100]	valid_0's auc: 0.964838
# [2150]	valid_0's auc: 0.965155
# [2200]	valid_0's auc: 0.965328
# [2250]	valid_0's auc: 0.965547
# [2300]	valid_0's auc: 0.965767
# [2350]	valid_0's auc: 0.965966
# [2400]	valid_0's auc: 0.966213
# [2450]	valid_0's auc: 0.966483
# [2500]	valid_0's auc: 0.966649
# [2550]	valid_0's auc: 0.966866
# [2600]	valid_0's auc: 0.966953
# [2650]	valid_0's auc: 0.967082
# [2700]	valid_0's auc: 0.967347
# [2750]	valid_0's auc: 0.967447
# [2800]	valid_0's auc: 0.967547
# [2850]	valid_0's auc: 0.96766
# [2900]	valid_0's auc: 0.967829
# [2950]	valid_0's auc: 0.967979
# [3000]	valid_0's auc: 0.968122
# [3050]	valid_0's auc: 0.968141
# [3100]	valid_0's auc: 0.968295
# [3150]	valid_0's auc: 0.968391
# [3200]	valid_0's auc: 0.968548
# [3250]	valid_0's auc: 0.968662
# [3300]	valid_0's auc: 0.968825
# [3350]	valid_0's auc: 0.968895
# [3400]	valid_0's auc: 0.969047
# [3450]	valid_0's auc: 0.96905
# [3500]	valid_0's auc: 0.969163
# [3550]	valid_0's auc: 0.969221
# [3600]	valid_0's auc: 0.969309
# [3650]	valid_0's auc: 0.969313
# [3700]	valid_0's auc: 0.969434
# [3750]	valid_0's auc: 0.969566
# [3800]	valid_0's auc: 0.969681
# [3850]	valid_0's auc: 0.969748
# [3900]	valid_0's auc: 0.969733
# Early stopping, best iteration is:
# [3869]	valid_0's auc: 0.969763
#  Fold 4 AUC-ROC : 0.9698 | Best Iteration: 3869
#    Accuracy    : 0.9870
#    Precision_0 : 0.9874 | Precision_1 : 0.9717
#    Recall_0    : 0.9993 | Recall_1    : 0.6476
#    F1 Score_0  : 0.9933 | F1 Score_1  : 0.7772
#
#  Fold 5
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's auc: 0.892145
# [100]	valid_0's auc: 0.91282
# [150]	valid_0's auc: 0.923641
# [200]	valid_0's auc: 0.929293
# [250]	valid_0's auc: 0.932744
# [300]	valid_0's auc: 0.936342
# [350]	valid_0's auc: 0.939612
# [400]	valid_0's auc: 0.943132
# [450]	valid_0's auc: 0.945192
# [500]	valid_0's auc: 0.946946
# [550]	valid_0's auc: 0.94842
# [600]	valid_0's auc: 0.949603
# [650]	valid_0's auc: 0.95099
# [700]	valid_0's auc: 0.951914
# [750]	valid_0's auc: 0.9527
# [800]	valid_0's auc: 0.95377
# [850]	valid_0's auc: 0.954827
# [900]	valid_0's auc: 0.95564
# [950]	valid_0's auc: 0.956669
# [1000]	valid_0's auc: 0.957273
# [1050]	valid_0's auc: 0.957581
# [1100]	valid_0's auc: 0.958208
# [1150]	valid_0's auc: 0.958679
# [1200]	valid_0's auc: 0.959015
# [1250]	valid_0's auc: 0.959689
# [1300]	valid_0's auc: 0.960159
# [1350]	valid_0's auc: 0.96057
# [1400]	valid_0's auc: 0.960812
# [1450]	valid_0's auc: 0.961186
# [1500]	valid_0's auc: 0.961385
# [1550]	valid_0's auc: 0.961549
# [1600]	valid_0's auc: 0.961987
# [1650]	valid_0's auc: 0.962276
# [1700]	valid_0's auc: 0.962695
# [1750]	valid_0's auc: 0.962993
# [1800]	valid_0's auc: 0.963168
# [1850]	valid_0's auc: 0.963504
# [1900]	valid_0's auc: 0.963741
# [1950]	valid_0's auc: 0.964047
# [2000]	valid_0's auc: 0.964569
# [2050]	valid_0's auc: 0.964767
# [2100]	valid_0's auc: 0.964908
# [2150]	valid_0's auc: 0.965185
# [2200]	valid_0's auc: 0.96529
# [2250]	valid_0's auc: 0.96539
# [2300]	valid_0's auc: 0.96547
# [2350]	valid_0's auc: 0.965726
# [2400]	valid_0's auc: 0.965991
# [2450]	valid_0's auc: 0.966188
# [2500]	valid_0's auc: 0.966284
# [2550]	valid_0's auc: 0.966456
# [2600]	valid_0's auc: 0.966649
# [2650]	valid_0's auc: 0.96691
# [2700]	valid_0's auc: 0.966937
# [2750]	valid_0's auc: 0.967125
# [2800]	valid_0's auc: 0.967394
# [2850]	valid_0's auc: 0.967515
# [2900]	valid_0's auc: 0.967643
# [2950]	valid_0's auc: 0.967861
# [3000]	valid_0's auc: 0.967975
# [3050]	valid_0's auc: 0.968098
# [3100]	valid_0's auc: 0.968152
# [3150]	valid_0's auc: 0.968291
# [3200]	valid_0's auc: 0.968443
# [3250]	valid_0's auc: 0.968508
# [3300]	valid_0's auc: 0.9686
# [3350]	valid_0's auc: 0.968813
# [3400]	valid_0's auc: 0.968927
# [3450]	valid_0's auc: 0.969004
# [3500]	valid_0's auc: 0.969124
# [3550]	valid_0's auc: 0.969212
# [3600]	valid_0's auc: 0.969365
# [3650]	valid_0's auc: 0.96963
# [3700]	valid_0's auc: 0.969803
# [3750]	valid_0's auc: 0.969836
# [3800]	valid_0's auc: 0.969977
# [3850]	valid_0's auc: 0.970065
# [3900]	valid_0's auc: 0.970146
# [3950]	valid_0's auc: 0.970137
# Early stopping, best iteration is:
# [3916]	valid_0's auc: 0.970154
#  Fold 5 AUC-ROC : 0.9702 | Best Iteration: 3916
#    Accuracy    : 0.9879
#    Precision_0 : 0.9884 | Precision_1 : 0.9681
#    Recall_0    : 0.9992 | Recall_1    : 0.6762
#    F1 Score_0  : 0.9938 | F1 Score_1  : 0.7962
#
#  Fold 6
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's auc: 0.896123
# [100]	valid_0's auc: 0.916255
# [150]	valid_0's auc: 0.925144
# [200]	valid_0's auc: 0.930893
# [250]	valid_0's auc: 0.934649
# [300]	valid_0's auc: 0.937564
# [350]	valid_0's auc: 0.940838
# [400]	valid_0's auc: 0.942718
# [450]	valid_0's auc: 0.945261
# [500]	valid_0's auc: 0.946712
# [550]	valid_0's auc: 0.948425
# [600]	valid_0's auc: 0.949882
# [650]	valid_0's auc: 0.951345
# [700]	valid_0's auc: 0.952332
# [750]	valid_0's auc: 0.953194
# [800]	valid_0's auc: 0.954327
# [850]	valid_0's auc: 0.955063
# [900]	valid_0's auc: 0.956001
# [950]	valid_0's auc: 0.957162
# [1000]	valid_0's auc: 0.957879
# [1050]	valid_0's auc: 0.958376
# [1100]	valid_0's auc: 0.958807
# [1150]	valid_0's auc: 0.9596
# [1200]	valid_0's auc: 0.960056
# [1250]	valid_0's auc: 0.960537
# [1300]	valid_0's auc: 0.961025
# [1350]	valid_0's auc: 0.961573
# [1400]	valid_0's auc: 0.961988
# [1450]	valid_0's auc: 0.962456
# [1500]	valid_0's auc: 0.962928
# [1550]	valid_0's auc: 0.963554
# [1600]	valid_0's auc: 0.964134
# [1650]	valid_0's auc: 0.964513
# [1700]	valid_0's auc: 0.964835
# [1750]	valid_0's auc: 0.965167
# [1800]	valid_0's auc: 0.965442
# [1850]	valid_0's auc: 0.96571
# [1900]	valid_0's auc: 0.965883
# [1950]	valid_0's auc: 0.966141
# [2000]	valid_0's auc: 0.966289
# [2050]	valid_0's auc: 0.966534
# [2100]	valid_0's auc: 0.96668
# [2150]	valid_0's auc: 0.96694
# [2200]	valid_0's auc: 0.967234
# [2250]	valid_0's auc: 0.967411
# [2300]	valid_0's auc: 0.967647
# [2350]	valid_0's auc: 0.967894
# [2400]	valid_0's auc: 0.968088
# [2450]	valid_0's auc: 0.968317
# [2500]	valid_0's auc: 0.968355
# [2550]	valid_0's auc: 0.968556
# [2600]	valid_0's auc: 0.968714
# [2650]	valid_0's auc: 0.968896
# [2700]	valid_0's auc: 0.969191
# [2750]	valid_0's auc: 0.969358
# [2800]	valid_0's auc: 0.969544
# [2850]	valid_0's auc: 0.969702
# [2900]	valid_0's auc: 0.969827
# [2950]	valid_0's auc: 0.970094
# [3000]	valid_0's auc: 0.970231
# [3050]	valid_0's auc: 0.970411
# [3100]	valid_0's auc: 0.970666
# [3150]	valid_0's auc: 0.970807
# [3200]	valid_0's auc: 0.970883
# [3250]	valid_0's auc: 0.971166
# [3300]	valid_0's auc: 0.971334
# [3350]	valid_0's auc: 0.971547
# [3400]	valid_0's auc: 0.971651
# [3450]	valid_0's auc: 0.971728
# [3500]	valid_0's auc: 0.971832
# [3550]	valid_0's auc: 0.971918
# [3600]	valid_0's auc: 0.972086
# [3650]	valid_0's auc: 0.972181
# [3700]	valid_0's auc: 0.972292
# [3750]	valid_0's auc: 0.97243
# [3800]	valid_0's auc: 0.972518
# [3850]	valid_0's auc: 0.972588
# [3900]	valid_0's auc: 0.972662
# [3950]	valid_0's auc: 0.972776
# [4000]	valid_0's auc: 0.972847
# [4050]	valid_0's auc: 0.973027
# [4100]	valid_0's auc: 0.973115
# [4150]	valid_0's auc: 0.973314
# [4200]	valid_0's auc: 0.973325
# Early stopping, best iteration is:
# [4157]	valid_0's auc: 0.973347
#  Fold 6 AUC-ROC : 0.9733 | Best Iteration: 4157
#    Accuracy    : 0.9881
#    Precision_0 : 0.9889 | Precision_1 : 0.9602
#    Recall_0    : 0.9990 | Recall_1    : 0.6897
#    F1 Score_0  : 0.9939 | F1 Score_1  : 0.8028
#
#  Fold 7
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's auc: 0.89919
# [100]	valid_0's auc: 0.918487
# [150]	valid_0's auc: 0.928745
# [200]	valid_0's auc: 0.934917
# [250]	valid_0's auc: 0.937667
# [300]	valid_0's auc: 0.940706
# [350]	valid_0's auc: 0.943455
# [400]	valid_0's auc: 0.945431
# [450]	valid_0's auc: 0.947387
# [500]	valid_0's auc: 0.949055
# [550]	valid_0's auc: 0.950651
# [600]	valid_0's auc: 0.95205
# [650]	valid_0's auc: 0.953157
# [700]	valid_0's auc: 0.954176
# [750]	valid_0's auc: 0.955313
# [800]	valid_0's auc: 0.956388
# [850]	valid_0's auc: 0.956998
# [900]	valid_0's auc: 0.957669
# [950]	valid_0's auc: 0.95834
# [1000]	valid_0's auc: 0.959626
# [1050]	valid_0's auc: 0.960469
# [1100]	valid_0's auc: 0.961083
# [1150]	valid_0's auc: 0.961709
# [1200]	valid_0's auc: 0.962239
# [1250]	valid_0's auc: 0.962773
# [1300]	valid_0's auc: 0.963161
# [1350]	valid_0's auc: 0.963728
# [1400]	valid_0's auc: 0.964071
# [1450]	valid_0's auc: 0.964525
# [1500]	valid_0's auc: 0.964955
# [1550]	valid_0's auc: 0.96527
# [1600]	valid_0's auc: 0.965452
# [1650]	valid_0's auc: 0.96593
# [1700]	valid_0's auc: 0.966194
# [1750]	valid_0's auc: 0.966569
# [1800]	valid_0's auc: 0.966865
# [1850]	valid_0's auc: 0.967076
# [1900]	valid_0's auc: 0.967265
# [1950]	valid_0's auc: 0.967571
# [2000]	valid_0's auc: 0.967881
# [2050]	valid_0's auc: 0.968268
# [2100]	valid_0's auc: 0.968621
# [2150]	valid_0's auc: 0.969001
# [2200]	valid_0's auc: 0.969553
# [2250]	valid_0's auc: 0.969758
# [2300]	valid_0's auc: 0.969987
# [2350]	valid_0's auc: 0.970154
# [2400]	valid_0's auc: 0.970378
# [2450]	valid_0's auc: 0.970549
# [2500]	valid_0's auc: 0.970798
# [2550]	valid_0's auc: 0.971007
# [2600]	valid_0's auc: 0.971155
# [2650]	valid_0's auc: 0.971314
# [2700]	valid_0's auc: 0.971452
# [2750]	valid_0's auc: 0.971822
# [2800]	valid_0's auc: 0.971862
# [2850]	valid_0's auc: 0.972142
# [2900]	valid_0's auc: 0.972286
# [2950]	valid_0's auc: 0.972461
# [3000]	valid_0's auc: 0.972575
# [3050]	valid_0's auc: 0.972859
# [3100]	valid_0's auc: 0.973096
# [3150]	valid_0's auc: 0.973181
# [3200]	valid_0's auc: 0.973343
# [3250]	valid_0's auc: 0.973476
# [3300]	valid_0's auc: 0.973592
# [3350]	valid_0's auc: 0.973679
# [3400]	valid_0's auc: 0.973797
# [3450]	valid_0's auc: 0.973977
# [3500]	valid_0's auc: 0.974086
# [3550]	valid_0's auc: 0.974202
# [3600]	valid_0's auc: 0.974194
# [3650]	valid_0's auc: 0.97444
# [3700]	valid_0's auc: 0.974464
# [3750]	valid_0's auc: 0.974653
# [3800]	valid_0's auc: 0.974707
# [3850]	valid_0's auc: 0.974858
# [3900]	valid_0's auc: 0.974917
# [3950]	valid_0's auc: 0.97495
# [4000]	valid_0's auc: 0.975018
# [4050]	valid_0's auc: 0.975186
# [4100]	valid_0's auc: 0.975282
# [4150]	valid_0's auc: 0.975354
# [4200]	valid_0's auc: 0.975415
# [4250]	valid_0's auc: 0.975481
# [4300]	valid_0's auc: 0.975552
# [4350]	valid_0's auc: 0.975569
# Early stopping, best iteration is:
# [4321]	valid_0's auc: 0.97561
#  Fold 7 AUC-ROC : 0.9756 | Best Iteration: 4321
#    Accuracy    : 0.9878
#    Precision_0 : 0.9883 | Precision_1 : 0.9687
#    Recall_0    : 0.9992 | Recall_1    : 0.6738
#    F1 Score_0  : 0.9937 | F1 Score_1  : 0.7947
#
#  Fold 8
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's auc: 0.893837
# [100]	valid_0's auc: 0.913152
# [150]	valid_0's auc: 0.923456
# [200]	valid_0's auc: 0.930027
# [250]	valid_0's auc: 0.934453
# [300]	valid_0's auc: 0.937953
# [350]	valid_0's auc: 0.940381
# [400]	valid_0's auc: 0.942819
# [450]	valid_0's auc: 0.945114
# [500]	valid_0's auc: 0.947273
# [550]	valid_0's auc: 0.948909
# [600]	valid_0's auc: 0.949817
# [650]	valid_0's auc: 0.951253
# [700]	valid_0's auc: 0.952375
# [750]	valid_0's auc: 0.953552
# [800]	valid_0's auc: 0.954574
# [850]	valid_0's auc: 0.955317
# [900]	valid_0's auc: 0.956236
# [950]	valid_0's auc: 0.956907
# [1000]	valid_0's auc: 0.957454
# [1050]	valid_0's auc: 0.958274
# [1100]	valid_0's auc: 0.958924
# [1150]	valid_0's auc: 0.959527
# [1200]	valid_0's auc: 0.960133
# [1250]	valid_0's auc: 0.961026
# [1300]	valid_0's auc: 0.961599
# [1350]	valid_0's auc: 0.962123
# [1400]	valid_0's auc: 0.962505
# [1450]	valid_0's auc: 0.962969
# [1500]	valid_0's auc: 0.963455
# [1550]	valid_0's auc: 0.963984
# [1600]	valid_0's auc: 0.964471
# [1650]	valid_0's auc: 0.964848
# [1700]	valid_0's auc: 0.965399
# [1750]	valid_0's auc: 0.965797
# [1800]	valid_0's auc: 0.966261
# [1850]	valid_0's auc: 0.966625
# [1900]	valid_0's auc: 0.966892
# [1950]	valid_0's auc: 0.96726
# [2000]	valid_0's auc: 0.967407
# [2050]	valid_0's auc: 0.967635
# [2100]	valid_0's auc: 0.96799
# [2150]	valid_0's auc: 0.968223
# [2200]	valid_0's auc: 0.968526
# [2250]	valid_0's auc: 0.968734
# [2300]	valid_0's auc: 0.969057
# [2350]	valid_0's auc: 0.969332
# [2400]	valid_0's auc: 0.969557
# [2450]	valid_0's auc: 0.969725
# [2500]	valid_0's auc: 0.970013
# [2550]	valid_0's auc: 0.970306
# [2600]	valid_0's auc: 0.970478
# [2650]	valid_0's auc: 0.970716
# [2700]	valid_0's auc: 0.970899
# [2750]	valid_0's auc: 0.971079
# [2800]	valid_0's auc: 0.971332
# [2850]	valid_0's auc: 0.971455
# [2900]	valid_0's auc: 0.97165
# [2950]	valid_0's auc: 0.971789
# [3000]	valid_0's auc: 0.971907
# [3050]	valid_0's auc: 0.972012
# [3100]	valid_0's auc: 0.9722
# [3150]	valid_0's auc: 0.972313
# [3200]	valid_0's auc: 0.972533
# [3250]	valid_0's auc: 0.972785
# [3300]	valid_0's auc: 0.972877
# [3350]	valid_0's auc: 0.972975
# [3400]	valid_0's auc: 0.973057
# [3450]	valid_0's auc: 0.973167
# [3500]	valid_0's auc: 0.9733
# [3550]	valid_0's auc: 0.973488
# [3600]	valid_0's auc: 0.97358
# [3650]	valid_0's auc: 0.973736
# [3700]	valid_0's auc: 0.973744
# [3750]	valid_0's auc: 0.973884
# [3800]	valid_0's auc: 0.973958
# [3850]	valid_0's auc: 0.974067
# [3900]	valid_0's auc: 0.974181
# [3950]	valid_0's auc: 0.974212
# [4000]	valid_0's auc: 0.974484
# [4050]	valid_0's auc: 0.974623
# [4100]	valid_0's auc: 0.974704
# [4150]	valid_0's auc: 0.974804
# [4200]	valid_0's auc: 0.974891
# [4250]	valid_0's auc: 0.974974
# [4300]	valid_0's auc: 0.974996
# [4350]	valid_0's auc: 0.975079
# [4400]	valid_0's auc: 0.975212
# [4450]	valid_0's auc: 0.975213
# [4500]	valid_0's auc: 0.975341
# [4550]	valid_0's auc: 0.975438
# [4600]	valid_0's auc: 0.975491
# [4650]	valid_0's auc: 0.975543
# [4700]	valid_0's auc: 0.975632
# [4750]	valid_0's auc: 0.975687
# [4800]	valid_0's auc: 0.975652
# Early stopping, best iteration is:
# [4750]	valid_0's auc: 0.975687
#  Fold 8 AUC-ROC : 0.9757 | Best Iteration: 4750
#    Accuracy    : 0.9881
#    Precision_0 : 0.9885 | Precision_1 : 0.9723
#    Recall_0    : 0.9993 | Recall_1    : 0.6797
#    F1 Score_0  : 0.9939 | F1 Score_1  : 0.8001
#
#  Fold 9
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's auc: 0.892335
# [100]	valid_0's auc: 0.912342
# [150]	valid_0's auc: 0.921923
# [200]	valid_0's auc: 0.927714
# [250]	valid_0's auc: 0.930394
# [300]	valid_0's auc: 0.934197
# [350]	valid_0's auc: 0.936856
# [400]	valid_0's auc: 0.939384
# [450]	valid_0's auc: 0.941475
# [500]	valid_0's auc: 0.943758
# [550]	valid_0's auc: 0.945136
# [600]	valid_0's auc: 0.946966
# [650]	valid_0's auc: 0.948249
# [700]	valid_0's auc: 0.949359
# [750]	valid_0's auc: 0.949979
# [800]	valid_0's auc: 0.950784
# [850]	valid_0's auc: 0.952955
# [900]	valid_0's auc: 0.954077
# [950]	valid_0's auc: 0.954605
# [1000]	valid_0's auc: 0.955248
# [1050]	valid_0's auc: 0.956791
# [1100]	valid_0's auc: 0.957533
# [1150]	valid_0's auc: 0.9579
# [1200]	valid_0's auc: 0.958557
# [1250]	valid_0's auc: 0.959338
# [1300]	valid_0's auc: 0.960236
# [1350]	valid_0's auc: 0.960682
# [1400]	valid_0's auc: 0.960993
# [1450]	valid_0's auc: 0.961555
# [1500]	valid_0's auc: 0.961932
# [1550]	valid_0's auc: 0.96248
# [1600]	valid_0's auc: 0.962886
# [1650]	valid_0's auc: 0.963141
# [1700]	valid_0's auc: 0.963403
# [1750]	valid_0's auc: 0.963619
# [1800]	valid_0's auc: 0.963916
# [1850]	valid_0's auc: 0.964396
# [1900]	valid_0's auc: 0.964751
# [1950]	valid_0's auc: 0.96511
# [2000]	valid_0's auc: 0.9655
# [2050]	valid_0's auc: 0.965883
# [2100]	valid_0's auc: 0.966042
# [2150]	valid_0's auc: 0.966319
# [2200]	valid_0's auc: 0.966718
# [2250]	valid_0's auc: 0.966921
# [2300]	valid_0's auc: 0.967252
# [2350]	valid_0's auc: 0.967577
# [2400]	valid_0's auc: 0.96772
# [2450]	valid_0's auc: 0.967928
# [2500]	valid_0's auc: 0.968118
# [2550]	valid_0's auc: 0.968276
# [2600]	valid_0's auc: 0.968445
# [2650]	valid_0's auc: 0.96856
# [2700]	valid_0's auc: 0.968785
# [2750]	valid_0's auc: 0.968917
# [2800]	valid_0's auc: 0.96903
# [2850]	valid_0's auc: 0.96934
# [2900]	valid_0's auc: 0.969493
# [2950]	valid_0's auc: 0.96963
# [3000]	valid_0's auc: 0.969739
# [3050]	valid_0's auc: 0.96989
# [3100]	valid_0's auc: 0.969984
# [3150]	valid_0's auc: 0.970039
# [3200]	valid_0's auc: 0.970123
# [3250]	valid_0's auc: 0.970364
# [3300]	valid_0's auc: 0.970486
# [3350]	valid_0's auc: 0.970628
# [3400]	valid_0's auc: 0.97079
# [3450]	valid_0's auc: 0.970891
# [3500]	valid_0's auc: 0.970965
# [3550]	valid_0's auc: 0.971072
# [3600]	valid_0's auc: 0.971112
# [3650]	valid_0's auc: 0.97126
# [3700]	valid_0's auc: 0.971325
# [3750]	valid_0's auc: 0.971375
# [3800]	valid_0's auc: 0.971474
# [3850]	valid_0's auc: 0.971576
# [3900]	valid_0's auc: 0.971709
# [3950]	valid_0's auc: 0.971752
# [4000]	valid_0's auc: 0.971827
# [4050]	valid_0's auc: 0.971928
# [4100]	valid_0's auc: 0.972135
# [4150]	valid_0's auc: 0.972114
# Early stopping, best iteration is:
# [4102]	valid_0's auc: 0.972143
#  Fold 9 AUC-ROC : 0.9721 | Best Iteration: 4102
#    Accuracy    : 0.9867
#    Precision_0 : 0.9873 | Precision_1 : 0.9611
#    Recall_0    : 0.9991 | Recall_1    : 0.6454
#    F1 Score_0  : 0.9931 | F1 Score_1  : 0.7722
#
#  Fold 10
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's auc: 0.903795
# [100]	valid_0's auc: 0.922308
# [150]	valid_0's auc: 0.931044
# [200]	valid_0's auc: 0.935926
# [250]	valid_0's auc: 0.9403
# [300]	valid_0's auc: 0.943319
# [350]	valid_0's auc: 0.945521
# [400]	valid_0's auc: 0.947943
# [450]	valid_0's auc: 0.950263
# [500]	valid_0's auc: 0.95237
# [550]	valid_0's auc: 0.953796
# [600]	valid_0's auc: 0.955259
# [650]	valid_0's auc: 0.956779
# [700]	valid_0's auc: 0.958042
# [750]	valid_0's auc: 0.95914
# [800]	valid_0's auc: 0.9599
# [850]	valid_0's auc: 0.960561
# [900]	valid_0's auc: 0.961396
# [950]	valid_0's auc: 0.962117
# [1000]	valid_0's auc: 0.962681
# [1050]	valid_0's auc: 0.963538
# [1100]	valid_0's auc: 0.963736
# [1150]	valid_0's auc: 0.96423
# [1200]	valid_0's auc: 0.964727
# [1250]	valid_0's auc: 0.965235
# [1300]	valid_0's auc: 0.965429
# [1350]	valid_0's auc: 0.966115
# [1400]	valid_0's auc: 0.96656
# [1450]	valid_0's auc: 0.966855
# [1500]	valid_0's auc: 0.967227
# [1550]	valid_0's auc: 0.967679
# [1600]	valid_0's auc: 0.968029
# [1650]	valid_0's auc: 0.968471
# [1700]	valid_0's auc: 0.968708
# [1750]	valid_0's auc: 0.969391
# [1800]	valid_0's auc: 0.969668
# [1850]	valid_0's auc: 0.969869
# [1900]	valid_0's auc: 0.970349
# [1950]	valid_0's auc: 0.970772
# [2000]	valid_0's auc: 0.971009
# [2050]	valid_0's auc: 0.971335
# [2100]	valid_0's auc: 0.971565
# [2150]	valid_0's auc: 0.97195
# [2200]	valid_0's auc: 0.972194
# [2250]	valid_0's auc: 0.972408
# [2300]	valid_0's auc: 0.97274
# [2350]	valid_0's auc: 0.973121
# [2400]	valid_0's auc: 0.973393
# [2450]	valid_0's auc: 0.973581
# [2500]	valid_0's auc: 0.973671
# [2550]	valid_0's auc: 0.973915
# [2600]	valid_0's auc: 0.97397
# [2650]	valid_0's auc: 0.974063
# [2700]	valid_0's auc: 0.974256
# [2750]	valid_0's auc: 0.974466
# [2800]	valid_0's auc: 0.974598
# [2850]	valid_0's auc: 0.97479
# [2900]	valid_0's auc: 0.974874
# [2950]	valid_0's auc: 0.975005
# [3000]	valid_0's auc: 0.975068
# [3050]	valid_0's auc: 0.975151
# [3100]	valid_0's auc: 0.975332
# [3150]	valid_0's auc: 0.975395
# [3200]	valid_0's auc: 0.975514
# [3250]	valid_0's auc: 0.975618
# [3300]	valid_0's auc: 0.975723
# [3350]	valid_0's auc: 0.975831
# [3400]	valid_0's auc: 0.975881
# [3450]	valid_0's auc: 0.976026
# [3500]	valid_0's auc: 0.976175
# [3550]	valid_0's auc: 0.97622
# [3600]	valid_0's auc: 0.976332
# [3650]	valid_0's auc: 0.976467
# [3700]	valid_0's auc: 0.976534
# [3750]	valid_0's auc: 0.976637
# [3800]	valid_0's auc: 0.976727
# [3850]	valid_0's auc: 0.97682
# [3900]	valid_0's auc: 0.976855
# [3950]	valid_0's auc: 0.976885
# [4000]	valid_0's auc: 0.976922
# [4050]	valid_0's auc: 0.976978
# [4100]	valid_0's auc: 0.977048
# [4150]	valid_0's auc: 0.977106
# [4200]	valid_0's auc: 0.977225
# [4250]	valid_0's auc: 0.977242
# [4300]	valid_0's auc: 0.977266
# Early stopping, best iteration is:
# [4284]	valid_0's auc: 0.977308
#  Fold 10 AUC-ROC : 0.9773 | Best Iteration: 4284
#    Accuracy    : 0.9878
#    Precision_0 : 0.9882 | Precision_1 : 0.9720
#    Recall_0    : 0.9993 | Recall_1    : 0.6715
#    F1 Score_0  : 0.9937 | F1 Score_1  : 0.7943
#
# Cross-Validation Results (LightGBM)
# Fold 1: AUC=0.9696 | Acc=0.9876 | Prec_0=0.9882 | Prec_1=0.9652 | Recall_0=0.9991 | Recall_1=0.6704 | F1_0=0.9936 | F1_1=0.7912
# Fold 2: AUC=0.9694 | Acc=0.9866 | Prec_0=0.9873 | Prec_1=0.9570 | Recall_0=0.9989 | Recall_1=0.6457 | F1_0=0.9931 | F1_1=0.7711
# Fold 3: AUC=0.9753 | Acc=0.9880 | Prec_0=0.9884 | Prec_1=0.9729 | Recall_0=0.9993 | Recall_1=0.6772 | F1_0=0.9938 | F1_1=0.7985
# Fold 4: AUC=0.9698 | Acc=0.9870 | Prec_0=0.9874 | Prec_1=0.9717 | Recall_0=0.9993 | Recall_1=0.6476 | F1_0=0.9933 | F1_1=0.7772
# Fold 5: AUC=0.9702 | Acc=0.9879 | Prec_0=0.9884 | Prec_1=0.9681 | Recall_0=0.9992 | Recall_1=0.6762 | F1_0=0.9938 | F1_1=0.7962
# Fold 6: AUC=0.9733 | Acc=0.9881 | Prec_0=0.9889 | Prec_1=0.9602 | Recall_0=0.9990 | Recall_1=0.6897 | F1_0=0.9939 | F1_1=0.8028
# Fold 7: AUC=0.9756 | Acc=0.9878 | Prec_0=0.9883 | Prec_1=0.9687 | Recall_0=0.9992 | Recall_1=0.6738 | F1_0=0.9937 | F1_1=0.7947
# Fold 8: AUC=0.9757 | Acc=0.9881 | Prec_0=0.9885 | Prec_1=0.9723 | Recall_0=0.9993 | Recall_1=0.6797 | F1_0=0.9939 | F1_1=0.8001
# Fold 9: AUC=0.9721 | Acc=0.9867 | Prec_0=0.9873 | Prec_1=0.9611 | Recall_0=0.9991 | Recall_1=0.6454 | F1_0=0.9931 | F1_1=0.7722
# Fold 10: AUC=0.9773 | Acc=0.9878 | Prec_0=0.9882 | Prec_1=0.9720 | Recall_0=0.9993 | Recall_1=0.6715 | F1_0=0.9937 | F1_1=0.7943
#
# Final Averages:
# AUC-ROC      : 0.9728 ± 0.0029
# Accuracy     : 0.9876
# Precision_0  : 0.9881
# Precision_1  : 0.9669
# Recall_0     : 0.9992
# Recall_1     : 0.6677
# F1 Score_0   : 0.9936
# F1 Score_1   : 0.7898
